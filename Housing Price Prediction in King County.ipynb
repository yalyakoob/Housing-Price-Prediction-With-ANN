# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # EDA/Data Cleaning/ Feature Engineering

# %%
df = pd.read_csv('/Users/youssefalyakoob/Desktop/Housing Price Prediction Using ANN/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price']); #distribution plot of target variable
# Out:
# /Users/youssefalyakoob/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/youssefalyakoob/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/youssefalyakoob/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# ...

# %%
sns.countplot(df['bedrooms']) #distribution of number of bedrooms
# Out:
# /Users/youssefalyakoob/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
#sqft_living has a strong correlation with the target variable (price)

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='sqft_living', y='price', data=df);

# %%
sns.boxplot(x='bedrooms', y='price', data=df); #distribution of prices/bedrooms

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='price', data=df);

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='lat',y='price', data=df);

# %%
#housing prices can vary based on longitude and latitude (ex.houses along a longitude of -122.2 are more expensive than others)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat', data=df, hue='price')

# %%
import plotly.express as px
px.set_mapbox_access_token('pk.eyJ1IjoieWFseWFrb29iIiwiYSI6ImNrcjVqaG14bDAyMDEyd3BmOHZpaXc1dmEifQ.QDxyZ7gUUU4H-S5NeE6SeQ')
fig = px.scatter_mapbox(data_frame = df, lat = 'lat', lon = 'long')
fig.show()
# Out:
# <div>                            <div id="1a6cd0b6-c5a1-4c1e-a4ee-cd58880e083c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a6cd0b6-c5a1-4c1e-a4ee-cd58880e083c")) {                    Plotly.newPlot(                        "1a6cd0b6-c5a1-4c1e-a4ee-cd58880e083c",                        [{"hovertemplate":"lat=%{lat}<br>long=%{lon}<extra></extra>","lat":[47.5112,47.721,47.7379,47.5208,47.6168,47.6561,47.3097,47.4095,47.5123,47.3684,47.6007,47.69,47.7558,47.6127,47.67,47.5714,47.7277,47.6648,47.3089,47.3343,47.7025,47.5316,47.3266,47.3533,47.3739,47.3048,47.6386,47.6221,47.695,47.7073,47.5391,47.7274,47.6823,47.6889,47.4276,47.6827,47.6621,47.6702,47.3341,47.5301,47.6145,47.445,47.6848,47.6413,47.4485,47.7443,47.3066,47.6194,47.6796,47.4041,47.4258
# ...

# %%
df.sort_values('price', ascending=False).head(20) #top 20 most expensive houses
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
df.shape
# Out:
# (21597, 21)

# %%
len(df) * 0.01 #216 houses in top 1 %
# Out:
# 215.97

# %%
#creating new df removing top 1% of houses/outliers
bottom_99 =  df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat', data= bottom_99,
                edgecolor=None, alpha=0.2,palette='RdYlGn',hue='price')

# %%
sns.boxplot(x='waterfront', y='price', data=df)

# %%
#houses on a waterfront tend to have higher prices

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
bottom_99 = bottom_99.drop('id', axis=1) #drop id column

# %%
bottom_99.head()
# Out:
#              date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 6329     6/2/2014  1970000.0         4       3.50         4370      8510
# 12271  10/15/2014  1960000.0         5       4.50         6200     23373
# 9166    2/13/2015  1960000.0         3       1.75         3330     12566
# 12565   4/22/2015  1960000.0         4       4.00         4430     31353
# 1150    4/21/2015  1960000.0         4       2.75         3120      7898
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 6329      2.0           0     1          3     10        3610            760
# 12271     3.0           0     1          4     11        5050           1150
# 9166      1.0           1     4          4      8        1940           1390
# 12565     2.0           0     0          3     12        4430              0
# 1150      1.0           1     4          4      8        1560           1560
#
# ...

# %%
bottom_99.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21381 entries, 6329 to 15279
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21381 non-null  object
#  1   price          21381 non-null  float64
#  2   bedrooms       21381 non-null  int64
#  3   bathrooms      21381 non-null  float64
#  4   sqft_living    21381 non-null  int64
#  5   sqft_lot       21381 non-null  int64
#  6   floors         21381 non-null  float64
#  7   waterfront     21381 non-null  int64
#  8   view           21381 non-null  int64
#  9   condition      21381 non-null  int64
#  10  grade          21381 non-null  int64
#  11  sqft_above     21381 non-null  int64
#  12  sqft_basement  21381 non-null  int64
#  13  yr_built       21381 non-null  int64
#  14  yr_renovated   21381 non-null  int64
#  15  zipcode        21381 non-null  int64
#  16  lat            21381 non-null  float64
# ...

# %%
#convert data feature into datatime object
bottom_99['date'] = pd.to_datetime(bottom_99['date'])

# %%
#create new year and month features from date feature 
bottom_99['year'] = bottom_99['date'].apply(lambda x: x.year)
bottom_99['month'] = bottom_99['date'].apply(lambda x: x.month)

# %%
bottom_99.head()
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 6329  2014-06-02  1970000.0         4       3.50         4370      8510
# 12271 2014-10-15  1960000.0         5       4.50         6200     23373
# 9166  2015-02-13  1960000.0         3       1.75         3330     12566
# 12565 2015-04-22  1960000.0         4       4.00         4430     31353
# 1150  2015-04-21  1960000.0         4       2.75         3120      7898
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# 6329      2.0           0     1          3  ...            760      2003
# 12271     3.0           0     1          4  ...           1150      1988
# 9166      1.0           1     4          4  ...           1390      1960
# 12565     2.0           0     0          3  ...              0      1998
# 1150      1.0           1     4          4  ...           1560      1963
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %% [markdown]
# examine distribution by months to see if houses sell for higher/lower during certain months

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month', y='price', data=bottom_99);

# %%
bottom_99.groupby('month').mean()['price'].plot();

# %%
bottom_99.groupby('year').mean()['price'].plot();

# %%
# drop original data column since we created year and month feature 
bottom_99 = bottom_99.drop('date', axis=1)

# %%
bottom_99.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6329   1970000.0         4       3.50         4370      8510     2.0
# 12271  1960000.0         5       4.50         6200     23373     3.0
# 9166   1960000.0         3       1.75         3330     12566     1.0
# 12565  1960000.0         4       4.00         4430     31353     2.0
# 1150   1960000.0         4       2.75         3120      7898     1.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 6329            0     1          3     10  ...            760      2003
# 12271           0     1          4     11  ...           1150      1988
# 9166            1     4          4      8  ...           1390      1960
# 12565           0     0          3     12  ...              0      1998
# 1150            1     4          4      8  ...           1560      1963
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %% [markdown]
# We need to transform the zipcode as a categorical variable as our model might assume that the feature is ordinal/continuous in nature.

# %%
bottom_99['zipcode'].nunique()
# Out:
# 70

# %% [markdown]
# We will drop the zip code column as there are 70 different unique values for that feature. One hot encoding a feature with a high cardinality can skew our model and add unneccessary dimensions to our df. An alternate option would be to use domain knowledge to group zip codes into a more reasonable geographical grouping

# %%
bottom_99 = bottom_99.drop('zipcode', axis=1)

# %%
#lets examine year renovated feature
bottom_99['yr_renovated'].value_counts()
# Out:
# 0       20499
# 2014       91
# 2013       36
# 2007       34
# 2003       34
#         ...
# 1954        1
# 1944        1
# 1951        1
# 1959        1
# 1948        1
# Name: yr_renovated, Length: 70, dtype: int64

# %% [markdown]
# An option would be to transform the yr_renovated column into a binary feature with 0 for not renovated and 1 for renovated. However, looking at the distribution of the feature above we can see that almost 96% of houses in our data were not renovated. We will drop this column as it will be hard to use this feature to establish rules of seperability for our model's predictions.

# %%
bottom_99 = bottom_99.drop('yr_renovated', axis=1)

# %%
bottom_99['sqft_basement'].value_counts()
# Out:
# 0       13052
# 600       219
# 700       214
# 500       214
# 800       205
#         ...
# 1990        1
# 1798        1
# 518         1
# 374         1
# 1135        1
# Name: sqft_basement, Length: 292, dtype: int64

# %%
bottom_99['sqft_basement'].value_counts(normalize=True)
# Out:
# 0       0.610449
# 600     0.010243
# 700     0.010009
# 500     0.010009
# 800     0.009588
#           ...
# 1990    0.000047
# 1798    0.000047
# 518     0.000047
# 374     0.000047
# 1135    0.000047
# Name: sqft_basement, Length: 292, dtype: float64

# %% [markdown]
# Similar to the yr_renovated feature. The majority of houses in our data do not have basments. It might be beneficial to drop this column as the rare labels can potentially create noise in our data and skew our model's predictions

# %%
bottom_99 = bottom_99.drop('sqft_basement', axis=1)

# %%
bottom_99.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# yr_built         0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# year             0
# month            0
# dtype: int64

# %% [markdown]
# # Data Preprocessing For Model

# %%
X = bottom_99.drop('price',axis=1).values #remove target variable from training data
y = bottom_99['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30, random_state=42)

# %%
#Data scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# # Building and Training our Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (14966, 17)

# %%
model = Sequential()
#adding 4 hidden layers with 17 neurons for each layer 
model.add(Dense(17,activation='relu'))
model.add(Dense(17,activation='relu'))
model.add(Dense(17,activation='relu'))
model.add(Dense(17,activation='relu'))
#output layer 
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train, validation_data=(X_test,y_test),
          batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 117/117 [==============================] - 1s 2ms/step - loss: 350631395328.0000 - val_loss: 348084535296.0000
# Epoch 2/400
# 117/117 [==============================] - 0s 1ms/step - loss: 349840769024.0000 - val_loss: 345439535104.0000
# Epoch 3/400
# 117/117 [==============================] - 0s 1ms/step - loss: 339711000576.0000 - val_loss: 322829189120.0000
# Epoch 4/400
# 117/117 [==============================] - 0s 2ms/step - loss: 291392913408.0000 - val_loss: 242078449664.0000
# Epoch 5/400
# 117/117 [==============================] - 0s 2ms/step - loss: 178799329280.0000 - val_loss: 112309788672.0000
# Epoch 6/400
# 117/117 [==============================] - 0s 2ms/step - loss: 77594378240.0000 - val_loss: 58326589440.0000
# Epoch 7/400
# 117/117 [==============================] - 0s 2ms/step - loss: 57313128448.0000 - val_loss: 55915483136.0000
# Epoch 8/400
# ...

# %% [markdown]
# # Model Evaluation

# %%
losses=pd.DataFrame(model.history.history)

# %%
losses.plot()

# %% [markdown]
# Based on the plot above we can see that there are no signs of overfitting as the training loss is consistent with validation and does not drop below the validation loss at the different epochs of training. We can potentially continue training the model as the validation loss does not seem to have reached an inflection point in which it is increasing

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 143358.70684957388

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 95984.30042868278

# %% [markdown]
# Based on the mean_absolute_error we can see that our predictions are off by roughly 95000 dollars

# %% [markdown]
# Another metric we can can evaluate is the explained variance score. Since a primary objective of any regression problem is to explain the variability in the dependent variable given the variability in the dependent variable we can use the explained variance score to see how much variability in the dependent variable our model explains

# %%
explained_variance_score(y_test,predictions) #model explains about 74 % of variability in dependent variable
# Out:
# 0.7435747343058707

# %%
#using model to predict price of individual house in our dataset
single_house=bottom_99.drop('price',axis=1).iloc[0]

# %%
single_house.values.reshape(-1,17)
# Out:
# array([[ 4.00000e+00,  3.50000e+00,  4.37000e+03,  8.51000e+03,
#          2.00000e+00,  0.00000e+00,  1.00000e+00,  3.00000e+00,
#          1.00000e+01,  3.61000e+03,  2.00300e+03,  4.75876e+01,
#         -1.22204e+02,  2.96000e+03,  1.03470e+04,  2.01400e+03,
#          6.00000e+00]])

# %%
single_house=scaler.transform(single_house.values.reshape(-1,17))

# %%
model.predict(single_house)
# Out:
# array([[1100625.5]], dtype=float32)

# %%
bottom_99.head(1)
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6329  1970000.0         4        3.5         4370      8510     2.0
#
#       waterfront  view  condition  grade  sqft_above  yr_built      lat  \
# 6329           0     1          3     10        3610      2003  47.5876
#
#          long  sqft_living15  sqft_lot15  year  month
# 6329 -122.204           2960       10347  2014      6

# %% [markdown]
# We can see that the true price of the house is 1.97 million but our model predicted a price of about 1.1 million. It looks like our model is undershooting predictions. A potential solution would be trying to gather more data on expensive houses and potentially engineer more features that would establish rules of seperability between houses at different price points
